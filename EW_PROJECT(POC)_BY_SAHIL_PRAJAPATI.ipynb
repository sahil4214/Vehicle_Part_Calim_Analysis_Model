# %%
import pandas as pd

# %%
sheet_names = pd.ExcelFile("/content/drive/MyDrive/Datascience files /DS_Projects/EW-Project/EW-Project/Dataset.xlsx").sheet_names

# %%
sheet_names
# Out:
# ['Dealers', 'Customers', 'Claims', 'Parts', 'Transactions', 'Vendors']

# %%
df = {sheet: pd.read_excel("/content/drive/MyDrive/Datascience files /DS_Projects/EW-Project/EW-Project/Dataset.xlsx", sheet_name=sheet) for sheet in sheet_names}

# %% [markdown]
# #operation on 'Dealers' sheet

# %%
df_dealers = df['Dealers']

# %%
df_dealers.shape
# Out:
# (2000, 6)

# %%
df_dealers.head()
# Out:
#    Dealer_ID      Dealer_Name Dealer_Country      State       City  ZIpCode
# 0          1  Kenneth Schmitt          india        Goa      Panji   400001
# 1          2  Owen Mclaughlin          india      Delhi     Naoida   400002
# 2          3  Donald Repinski          india  Karnataka  Bangalore   400003
# 3          4    Rachel Oszust          india     Gujrat  Ahemdabad   400004
# 4          5       Lynn Knapp          india     Orrisa    Cuttack   400005

# %%
df_dealers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dealer_ID       2000 non-null   int64
#  1   Dealer_Name     2000 non-null   object
#  2   Dealer_Country  2000 non-null   object
#  3   State           2000 non-null   object
#  4   City            2000 non-null   object
#  5   ZIpCode         2000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 93.9+ KB

# %%
df_dealers.describe()
# Out:
#          Dealer_ID        ZIpCode
# count  2000.000000    2000.000000
# mean   1000.500000  400003.467500
# std     577.494589       1.720588
# min       1.000000  400001.000000
# 25%     500.750000  400002.000000
# 50%    1000.500000  400003.000000
# 75%    1500.250000  400005.000000
# max    2000.000000  400006.000000

# %%
df_dealers.describe(include='all')
# Out:
#           Dealer_ID        Dealer_Name Dealer_Country State   City  \
# count   2000.000000               2000           2000  2000   2000
# unique          NaN               1994              1     6      6
# top             NaN  Michael Zimmerman          india   Goa  Panji
# freq            NaN                  2           2000   355    355
# mean    1000.500000                NaN            NaN   NaN    NaN
# std      577.494589                NaN            NaN   NaN    NaN
# min        1.000000                NaN            NaN   NaN    NaN
# 25%      500.750000                NaN            NaN   NaN    NaN
# 50%     1000.500000                NaN            NaN   NaN    NaN
# 75%     1500.250000                NaN            NaN   NaN    NaN
# max     2000.000000                NaN            NaN   NaN    NaN
#
#               ZIpCode
# count     2000.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    400003.467500
# ...

# %%
df_dealers.isnull().sum()
# Out:
# Dealer_ID         0
# Dealer_Name       0
# Dealer_Country    0
# State             0
# City              0
# ZIpCode           0
# dtype: int64

# %%
df_dealers.duplicated().sum()
# Out:
# 0

# %%
df_dealers.columns
# Out:
# Index(['Dealer_ID', 'Dealer_Name', 'Dealer_Country', 'State', 'City',
#        'ZIpCode'],
#       dtype='object')

# %% [markdown]
# #operation on 'Customers' sheet

# %%
df_customers = df['Customers']

# %%
df_customers.shape
# Out:
# (288000, 7)

# %%
df_customers.head()
# Out:
#    Cust_ID Cust_Name  Dealer_ID Country      State        City  ZipCode
# 0      101   pushpak          1     ind        goa      panaji   402201
# 1      102       raj          3     ind  karnataka    banglore   403315
# 2      103    ranbir          4     ind     gujrat  ahemadabad   326665
# 3      104   reyansh          5     ind     orrisa     cuttack   543211
# 4      105    raunak          2     ind      delhi       noida   426232

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288000 entries, 0 to 287999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Cust_ID    288000 non-null  int64
#  1   Cust_Name  288000 non-null  object
#  2   Dealer_ID  288000 non-null  int64
#  3   Country    288000 non-null  object
#  4   State      288000 non-null  object
#  5   City       288000 non-null  object
#  6   ZipCode    288000 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 15.4+ MB

# %%
df_customers.describe()
# Out:
#              Cust_ID      Dealer_ID        ZipCode
# count  288000.000000  288000.000000  288000.000000
# mean   144094.207639     334.681500  418703.183000
# std     83128.373098     435.187113   90349.326236
# min       101.000000       1.000000  215432.000000
# 25%     72100.750000       5.000000  402201.000000
# 50%    144100.500000      84.000000  403315.000000
# 75%    216100.250000     971.000000  426232.000000
# max    288000.000000     991.000000  543211.000000

# %%
df_customers.describe(include='all')
# Out:
#               Cust_ID Cust_Name      Dealer_ID Country   State     City  \
# count   288000.000000    288000  288000.000000  288000  288000   288000
# unique            NaN       840            NaN       1       6        6
# top               NaN     James            NaN     ind  orrisa  cuttack
# freq              NaN      5472            NaN  288000   66960    66960
# mean    144094.207639       NaN     334.681500     NaN     NaN      NaN
# std      83128.373098       NaN     435.187113     NaN     NaN      NaN
# min        101.000000       NaN       1.000000     NaN     NaN      NaN
# 25%      72100.750000       NaN       5.000000     NaN     NaN      NaN
# 50%     144100.500000       NaN      84.000000     NaN     NaN      NaN
# 75%     216100.250000       NaN     971.000000     NaN     NaN      NaN
# max     288000.000000       NaN     991.000000     NaN     NaN      NaN
#
#               ZipCode
# count   288000.000000
# unique            NaN
# top               NaN
# ...

# %%
df_customers.isnull().sum()
# Out:
# Cust_ID      0
# Cust_Name    0
# Dealer_ID    0
# Country      0
# State        0
# City         0
# ZipCode      0
# dtype: int64

# %%
df_customers.duplicated().sum()
# Out:
# 0

# %%
df_customers.columns
# Out:
# Index(['Cust_ID', 'Cust_Name', 'Dealer_ID', 'Country', 'State', 'City',
#        'ZipCode'],
#       dtype='object')

# %% [markdown]
# #operation on 'Claims' sheet

# %%
df_claims = df['Claims']

# %%
df_claims.shape
# Out:
# (20095, 7)

# %%
df_claims.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000          5      104      901
# 1         2 2020-04-01         42000          6      106      902
# 2         3 2020-04-01         45000          4      103      903
# 3         4 2020-04-01         56000          3      102      904
# 4         5 2020-04-01         39000          2      105      905
#
#   Repair_or_Replace
# 0               rpr
# 1              rplc
# 2               rpr
# 3              rplc
# 4               rpr

# %%
df_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20095 entries, 0 to 20094
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_id           20095 non-null  int64
#  1   claim_date         20095 non-null  datetime64[ns]
#  2   claim_amount       20095 non-null  int64
#  3   Dealer_ID          20095 non-null  int64
#  4   Cust_ID            20095 non-null  int64
#  5   Part_ID            20095 non-null  int64
#  6   Repair_or_Replace  20095 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.1+ MB

# %%
df_claims.describe()
# Out:
#            claim_id                     claim_date  claim_amount  \
# count  20095.000000                          20095  20095.000000
# mean   10048.000000  2021-01-02 13:21:04.971385856  47032.843991
# min        1.000000            2020-04-01 00:00:00  25000.000000
# 25%     5024.500000            2021-01-24 00:00:00  37000.000000
# 50%    10048.000000            2021-01-24 00:00:00  48000.000000
# 75%    15071.500000            2021-01-24 00:00:00  56000.000000
# max    20095.000000            2021-01-24 00:00:00  69000.000000
# std     5801.071165                            NaN  12040.003994
#
#           Dealer_ID        Cust_ID       Part_ID
# count  20095.000000   20095.000000  20095.000000
# mean    1063.908236   84153.946803    904.266434
# min        1.000000     101.000000    901.000000
# 25%     1212.000000     126.000000    902.000000
# 50%     1241.000000   43934.000000    905.000000
# 75%     1269.000000  103320.000000    906.000000
# ...

# %%
df_claims.describe(include='all')
# Out:
#             claim_id                     claim_date  claim_amount  \
# count   20095.000000                          20095  20095.000000
# unique           NaN                            NaN           NaN
# top              NaN                            NaN           NaN
# freq             NaN                            NaN           NaN
# mean    10048.000000  2021-01-02 13:21:04.971385856  47032.843991
# min         1.000000            2020-04-01 00:00:00  25000.000000
# 25%      5024.500000            2021-01-24 00:00:00  37000.000000
# 50%     10048.000000            2021-01-24 00:00:00  48000.000000
# 75%     15071.500000            2021-01-24 00:00:00  56000.000000
# max     20095.000000            2021-01-24 00:00:00  69000.000000
# std      5801.071165                            NaN  12040.003994
#
#            Dealer_ID        Cust_ID       Part_ID Repair_or_Replace
# count   20095.000000   20095.000000  20095.000000             20095
# ...

# %%
df_claims.isnull().sum()
# Out:
# claim_id             0
# claim_date           0
# claim_amount         0
# Dealer_ID            0
# Cust_ID              0
# Part_ID              0
# Repair_or_Replace    0
# dtype: int64

# %%
df_claims.duplicated().sum()
# Out:
# 0

# %%
df_claims.columns
# Out:
# Index(['claim_id', 'claim_date', 'claim_amount', 'Dealer_ID', 'Cust_ID',
#        'Part_ID', 'Repair_or_Replace'],
#       dtype='object')

# %% [markdown]
# #operation on 'Parts' sheet

# %%
df_parts = df['Parts']

# %%
df_parts.shape
# Out:
# (11, 4)

# %%
df_parts.head(11)
# Out:
#     Part_ID          Part_Name  Manufacturer_ID  Manf_Date
# 0       901          brake pad              501 1996-08-12
# 1       902              axle               502 1997-03-03
# 2       903            tie rod              503 1997-06-13
# 3       904       differential              504 1997-01-14
# 4       905    rear suspension              505 1996-08-19
# 5       906           radiator              506 1997-03-24
# 6       907        clutch kits              503 1997-05-12
# 7       908    pressure plates              502 1997-05-20
# 8       909          flywheels              505 1997-06-29
# 9       910  torque converters              506 1997-07-17
# 10      911         flexplates              501 1997-08-23

# %%
df_parts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Part_ID          11 non-null     int64
#  1   Part_Name        11 non-null     object
#  2   Manufacturer_ID  11 non-null     int64
#  3   Manf_Date        11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 480.0+ bytes

# %%
df_parts.describe()
# Out:
#           Part_ID  Manufacturer_ID                      Manf_Date
# count   11.000000        11.000000                             11
# mean   906.000000       503.454545  1997-03-25 19:38:10.909090944
# min    901.000000       501.000000            1996-08-12 00:00:00
# 25%    903.500000       502.000000            1997-02-07 00:00:00
# 50%    906.000000       503.000000            1997-05-12 00:00:00
# 75%    908.500000       505.000000            1997-06-21 00:00:00
# max    911.000000       506.000000            1997-08-23 00:00:00
# std      3.316625         1.863525                            NaN

# %%
df_parts.describe(include='all')
# Out:
#            Part_ID  Part_Name  Manufacturer_ID                      Manf_Date
# count    11.000000         11        11.000000                             11
# unique         NaN         11              NaN                            NaN
# top            NaN  brake pad              NaN                            NaN
# freq           NaN          1              NaN                            NaN
# mean    906.000000        NaN       503.454545  1997-03-25 19:38:10.909090944
# min     901.000000        NaN       501.000000            1996-08-12 00:00:00
# 25%     903.500000        NaN       502.000000            1997-02-07 00:00:00
# 50%     906.000000        NaN       503.000000            1997-05-12 00:00:00
# 75%     908.500000        NaN       505.000000            1997-06-21 00:00:00
# max     911.000000        NaN       506.000000            1997-08-23 00:00:00
# std       3.316625        NaN         1.863525                            NaN

# %%
df_parts.isnull().sum()
# Out:
# Part_ID            0
# Part_Name          0
# Manufacturer_ID    0
# Manf_Date          0
# dtype: int64

# %%
df_parts.duplicated().sum()
# Out:
# 0

# %%
df_parts.columns
# Out:
# Index(['Part_ID', 'Part_Name', 'Manufacturer_ID', 'Manf_Date'], dtype='object')

# %% [markdown]
# # operation on 'Transactions' sheet

# %%
df_transactions = df['Transactions']

# %%
df_transactions.shape
# Out:
# (20095, 4)

# %%
df_transactions.head()
# Out:
#    transaction_id  claim_id transaction_date  transaction_amount
# 0             101         1       2020-04-01               36000
# 1             102         2       2020-04-01               42000
# 2             103         3       2020-04-01               45000
# 3             104         4       2020-04-01               56000
# 4             105         5       2020-04-01               39000

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20095 entries, 0 to 20094
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      20095 non-null  int64
#  1   claim_id            20095 non-null  int64
#  2   transaction_date    20095 non-null  datetime64[ns]
#  3   transaction_amount  20095 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 628.1 KB

# %%
df_transactions.describe()
# Out:
#        transaction_id      claim_id               transaction_date  \
# count    20095.000000  20095.000000                          20095
# mean     10062.680269  10048.000000  2021-01-02 13:21:04.971385856
# min        101.000000      1.000000            2020-04-01 00:00:00
# 25%       5024.500000   5024.500000            2021-01-24 00:00:00
# 50%      10048.000000  10048.000000            2021-01-24 00:00:00
# 75%      15071.500000  15071.500000            2021-01-24 00:00:00
# max      20095.000000  20095.000000            2021-01-24 00:00:00
# std       5779.444049   5801.071165                            NaN
#
#        transaction_amount
# count        20095.000000
# mean         47032.843991
# min          25000.000000
# 25%          37000.000000
# 50%          48000.000000
# 75%          56000.000000
# max          69000.000000
# std          12040.003994

# %%
df_transactions.describe(include='all')
# Out:
#        transaction_id      claim_id               transaction_date  \
# count    20095.000000  20095.000000                          20095
# mean     10062.680269  10048.000000  2021-01-02 13:21:04.971385856
# min        101.000000      1.000000            2020-04-01 00:00:00
# 25%       5024.500000   5024.500000            2021-01-24 00:00:00
# 50%      10048.000000  10048.000000            2021-01-24 00:00:00
# 75%      15071.500000  15071.500000            2021-01-24 00:00:00
# max      20095.000000  20095.000000            2021-01-24 00:00:00
# std       5779.444049   5801.071165                            NaN
#
#        transaction_amount
# count        20095.000000
# mean         47032.843991
# min          25000.000000
# 25%          37000.000000
# 50%          48000.000000
# 75%          56000.000000
# max          69000.000000
# std          12040.003994

# %%
df_transactions.isnull().sum()
# Out:
# transaction_id        0
# claim_id              0
# transaction_date      0
# transaction_amount    0
# dtype: int64

# %%
df_transactions.duplicated().sum()
# Out:
# 0

# %%
df_transactions.columns
# Out:
# Index(['transaction_id', 'claim_id', 'transaction_date', 'transaction_amount'], dtype='object')

# %% [markdown]
# #operation on 'Vendors' sheet

# %%
df_vendors = df['Vendors']

# %%
df_vendors.shape
# Out:
# (6, 6)

# %%
df_vendors.head()
# Out:
#    Vendor_ID     Name Country      State        City  ZIpCode
# 0        501    Advik     ind        goa      panaji   400001
# 1        502    Rudra     ind      delhi       noida   400002
# 2        503  Aayansh     ind  karnataka    banglore   400003
# 3        504   Adinew     ind     gujrat  ahemadabad   400004
# 4        505    Dhruv     ind     orrisa     cuttack   400005

# %%
df_vendors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Vendor_ID  6 non-null      int64
#  1   Name       6 non-null      object
#  2   Country    6 non-null      object
#  3   State      6 non-null      object
#  4   City       6 non-null      object
#  5   ZIpCode    6 non-null      int64
# dtypes: int64(2), object(4)
# memory usage: 416.0+ bytes

# %%
df_vendors.describe()
# Out:
#         Vendor_ID        ZIpCode
# count    6.000000       6.000000
# mean   503.500000  400003.500000
# std      1.870829       1.870829
# min    501.000000  400001.000000
# 25%    502.250000  400002.250000
# 50%    503.500000  400003.500000
# 75%    504.750000  400004.750000
# max    506.000000  400006.000000

# %%
df_vendors.describe(include='all')
# Out:
#          Vendor_ID   Name Country State    City        ZIpCode
# count     6.000000      6       6     6       6       6.000000
# unique         NaN      6       1     6       6            NaN
# top            NaN  Advik     ind   goa  panaji            NaN
# freq           NaN      1       6     1       1            NaN
# mean    503.500000    NaN     NaN   NaN     NaN  400003.500000
# std       1.870829    NaN     NaN   NaN     NaN       1.870829
# min     501.000000    NaN     NaN   NaN     NaN  400001.000000
# 25%     502.250000    NaN     NaN   NaN     NaN  400002.250000
# 50%     503.500000    NaN     NaN   NaN     NaN  400003.500000
# 75%     504.750000    NaN     NaN   NaN     NaN  400004.750000
# max     506.000000    NaN     NaN   NaN     NaN  400006.000000

# %%
df_vendors.isnull().sum()
# Out:
# Vendor_ID    0
# Name         0
# Country      0
# State        0
# City         0
# ZIpCode      0
# dtype: int64

# %%
df_vendors.duplicated().sum()
# Out:
# 0

# %%
df_vendors.columns
# Out:
# Index(['Vendor_ID', 'Name', 'Country', 'State', 'City', 'ZIpCode'], dtype='object')

# %% [markdown]
# #Data Preprocessing

# %%
#preprocessing on claims :
df_claims['claim_date'] = pd.to_datetime(df_claims['claim_date'])
df_claims['month_year'] = df_claims['claim_date'].dt.to_period('M')

# %%
#adding vehicle age column in df
df_claims['vehicle_age'] = (pd.to_datetime('today') - df_claims['claim_date']).dt.days // 365

# %%
df_claims.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000          5      104      901
# 1         2 2020-04-01         42000          6      106      902
# 2         3 2020-04-01         45000          4      103      903
# 3         4 2020-04-01         56000          3      102      904
# 4         5 2020-04-01         39000          2      105      905
#
#   Repair_or_Replace month_year  vehicle_age
# 0               rpr    2020-04            4
# 1              rplc    2020-04            4
# 2               rpr    2020-04            4
# 3              rplc    2020-04            4
# 4               rpr    2020-04            4

# %% [markdown]
# #Visualizations and Insights

# %% [markdown]
# #Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Distribution of claim amounts
plt.figure(figsize=(10, 6))
sns.histplot(df_claims['claim_amount'], bins=20, kde=True)
plt.title('Distribution of Claim Amounts')
plt.xlabel('Claim Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Claims over time
df_claims['claim_month'] = df_claims['claim_date'].dt.to_period('M')
claims_over_time = df_claims.groupby('claim_month').size().reset_index(name='counts')

# %%
claims_over_time['claim_month'] = claims_over_time['claim_month'].astype(str)

# %%
#Number of claimns over time

plt.figure(figsize=(12, 6))
sns.lineplot(data=claims_over_time, x='claim_month', y='counts')
plt.title('Number of Claims Over Time')
plt.xlabel('Month-Year')
plt.ylabel('Number of Claims')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

# %%
df_claims['claim_date'] = pd.to_datetime(df_claims['claim_date'])

# %%
df_claims['claim_month'] = df_claims['claim_date'].dt.to_period('M')

# %%
g = sns.FacetGrid(df_claims, col='claim_month', col_wrap=4, height=4)
g.map(sns.kdeplot, 'claim_amount', fill=True)
for ax in g.axes.flat:
    ax.set_title(ax.get_title().replace('claim_month = ', ''))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('KDE Plots of Claim Amount by Month')
plt.show()

# %%
df_claims['claim_amount'].skew()
# Out:
# -0.296373401353112

# %%
sns.kdeplot(data=df_claims, x='claim_amount', fill=True)
# Out:
# <Axes: xlabel='claim_amount', ylabel='Density'>

# %%
sns.boxplot(data=df_claims, x='claim_amount',fill=True)
# Out:
# <Axes: xlabel='claim_amount'>

# %% [markdown]
# #checking here most claim by january 2021 on which part

# %%
merged_df = pd.merge(df_claims, df_parts, on='Part_ID', how='inner')

# Now we Filter the data for months after January 2021
data_after_jan_2021 = merged_df[merged_df['claim_date'] > '2020-12-31']
# Group data by part name and count the number of claims for each part that we get for claim
claim_counts_by_part = data_after_jan_2021['Part_Name'].value_counts()
# part with the most claims we get here
most_claimed_part = claim_counts_by_part.idxmax()
num_claims_most_claimed_part = claim_counts_by_part.max()

# %%
print(f"The part with the most claims after January 2021 is '{most_claimed_part}' "f"with {num_claims_most_claimed_part} claims.")
# Out:
# The part with the most claims after January 2021 is 'radiator' with 3702 claims.

# %%
bar_plot = claim_counts_by_part.plot(kind='bar')
plt.title('Number of Claims by Part after January 2021')
plt.xlabel('Part Name')
plt.ylabel('Number of Claims')
plt.xticks(rotation=45)

for i, count in enumerate(claim_counts_by_part):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# **The part with the most claims after January 2021 is 'radiator' with 3702 claims.**

# %% [markdown]
# #checking same for all month with claim amount :

# %%
claims_by_part_month = merged_df.groupby(['Part_Name', 'claim_month']).agg({'claim_id': 'count', 'claim_amount': 'sum'})
claims_by_part_month.reset_index(inplace=True)
pivot_table = claims_by_part_month.pivot(index='Part_Name', columns='claim_month', values=['claim_id', 'claim_amount'])
print(pivot_table)
# Out:
#                 claim_id                                                  \
# claim_month      2020-04 2020-05 2020-06 2020-07 2020-08 2020-09 2020-10
# Part_Name
# axle                 134       3       3       3       3       3       3
# brake pad            224       5       5       5       5       5       5
# clutch kits          222       5       5       6       5       5       5
# differential         134       3       3       3       3       3       4
# radiator             268       7       6       6       6       6       6
# rear suspension      223       5       5       5       6       5       5
# tie rod              135       3       3       3       3       3       3
#
#                                         claim_amount                          \
# claim_month     2020-11 2020-12 2021-01      2020-04 2020-05 2020-06 2020-07
# Part_Name
# axle                  3       4    1851      6447000  144000  144000  144000
# ...

# %%
# Generate heatmap for total number of claims
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table['claim_id'], cmap='Blues', annot=True, fmt='g')
plt.title('Total Number of Claims by Part Name and Month')
plt.xlabel('Month')
plt.ylabel('Part Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Generate heatmap for total claim amount
plt.figure(figsize=(16, 8))
sns.heatmap(pivot_table['claim_amount'], cmap='Greens', annot=True, fmt='.2f')
plt.title('Total Claim Amount by Part Name and Month')
plt.xlabel('Month')
plt.ylabel('Part Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #checking here the claim product is replaced or repair

# %%
merged_df = pd.merge(df_claims, df_parts, on='Part_ID', how='inner')
claims_data = merged_df[['Part_Name', 'Repair_or_Replace', 'claim_month']]
claim_type_counts = claims_data.groupby(['Part_Name', 'Repair_or_Replace']).size().unstack(fill_value=0)
plt.figure(figsize=(12, 8))
claim_type_counts.plot(kind='bar', stacked=True)
plt.title('Distribution of Repair and Replacement Claims by Product')
plt.xlabel('Parts Name')
plt.ylabel('Number of Claims')
plt.xticks(rotation=45)
plt.legend(title='Repair or Replace')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Check the part_name from which state and city provided most claims :

# %%
merged_df = pd.merge(df_claims, df_parts, on='Part_ID', how='inner')
merged_df = pd.merge(merged_df, df_customers, on='Cust_ID', how='inner')

# %%
# Group data by State, City, and Part_Name, and count occurrences
claim_counts = merged_df.groupby(['State', 'City', 'Part_Name']).size().reset_index(name='Claim_Count')

# %%
# Determine whether the claims for each part from a city were mostly repaired or replaced
repair_or_replace = merged_df.groupby(['State', 'City', 'Part_Name', 'Repair_or_Replace']).size().unstack(fill_value=0)
repair_or_replace['Total'] = repair_or_replace.sum(axis=1)
repair_or_replace['Most_Common'] = repair_or_replace[['rplc', 'rpr']].idxmax(axis=1)
repair_or_replace = repair_or_replace[['Total', 'Most_Common']]

# %%
top_claimed = claim_counts.groupby('Part_Name').apply(lambda x: x.nlargest(1, 'Claim_Count')).reset_index(drop=True)

# %%
print("Top States and Cities with the Most Claims on Each Part:")
print(top_claimed)
# Out:
# Top States and Cities with the Most Claims on Each Part:
#     State     City        Part_Name  Claim_Count
# 0  orrisa  cuttack            axle           470
# 1  orrisa  cuttack        brake pad          793
# 2  orrisa  cuttack      clutch kits          738
# 3  orrisa  cuttack     differential          462
# 4  orrisa  cuttack         radiator          977
# 5  orrisa  cuttack  rear suspension          709
# 6  orrisa  cuttack          tie rod          464

# %%
print("Analysis of Repair or Replace for Parts from Cities:")
print(repair_or_replace)
# Out:
# Analysis of Repair or Replace for Parts from Cities:
# Repair_or_Replace                       Total Most_Common
# State       City       Part_Name
# delhi       noida      axle               426        rplc
#                        brake pad          675         rpr
#                        clutch kits        710        rplc
#                        differential       447        rplc
#                        radiator           775        rplc
#                        rear suspension    704        rplc
#                        tie rod            426        rplc
# goa         panaji     axle               383        rplc
#                        brake pad          653         rpr
#                        clutch kits        678        rplc
#                        differential       357        rplc
#                        radiator           823        rplc
#                        rear suspension    682        rplc
#                        tie rod            439        rplc
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=claim_counts, x='Part_Name', y='Claim_Count', hue='State', ci=None)
plt.title('Number of Claims by Part Name, State, and City')
plt.xlabel('Part Name')
plt.ylabel('Number of Claims')
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-87-ca254d020070>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=claim_counts, x='Part_Name', y='Claim_Count', hue='State', ci=None)

# %%
# Get the category with maximum claims for each city
max_claim_category = repair_or_replace.groupby(['City', 'Most_Common']).agg({'Total': 'max'}).reset_index()

# Merge with repair_or_replace to get the corresponding repair or replace type
max_claim_category = pd.merge(max_claim_category, repair_or_replace, on=['City', 'Most_Common', 'Total'], how='inner')

# Create bar plot for maximum claims by repair or replace type in each city
plt.figure(figsize=(12, 8))
sns.barplot(data=max_claim_category, x='City', y='Total', hue='Most_Common')

# Add labels and legend
plt.title('Maximum Claims by Repair or Replace Type in Each City')
plt.xlabel('City')
plt.ylabel('Number of Claims')
plt.legend(title='Repair or Replace', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Transaction amount by city on different parts

# %%
merged_df = pd.merge(df_transactions, df_claims, on='claim_id', how='inner')
merged_df = pd.merge(merged_df, df_parts, on='Part_ID', how='inner')
merged_df = pd.merge(merged_df, df_customers, on='Cust_ID', how='inner')

# %%
# Group by City and Part_Name to calculate the total transaction amount and claim count
grouped_df = merged_df.groupby(['City', 'Part_Name']).agg({'transaction_amount': 'sum','claim_id': 'count'}).reset_index()
grouped_df.columns = ['City', 'Part_Name', 'Total_Transaction_Amount', 'Claim_Count']

# %%
print(grouped_df.head(42))
# Out:
#           City        Part_Name  Total_Transaction_Amount  Claim_Count
# 0   ahemadabad            axle                    8982000          165
# 1   ahemadabad        brake pad                  11592000          228
# 2   ahemadabad      clutch kits                   8003000          201
# 3   ahemadabad     differential                   6344000          131
# 4   ahemadabad         radiator                  11870000          251
# 5   ahemadabad  rear suspension                  11354000          236
# 6   ahemadabad          tie rod                   7795000          153
# 7     banglore            axle                   16797000          350
# 8     banglore        brake pad                  35744000          679
# 9     banglore      clutch kits                  24811000          651
# 10    banglore     differential                  17007000          374
# 11    banglore         radiator                  36359000          767
# ...

# %%
# Total Transaction Amount
plt.figure(figsize=(14, 8))
sns.barplot(data=grouped_df, x='City', y='Total_Transaction_Amount', hue='Part_Name', ci=None)
plt.title('Total Transaction Amount by Part Name and City')
plt.xlabel('City')
plt.ylabel('Total Transaction Amount')
plt.xticks(rotation=45)
plt.legend(title='Part Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-92-4a839ae51814>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=grouped_df, x='City', y='Total_Transaction_Amount', hue='Part_Name', ci=None)

# %%
#for Claim Count
plt.figure(figsize=(14, 8))
sns.barplot(data=grouped_df, x='City', y='Claim_Count', hue='Part_Name', ci=None)
plt.title('Claim Count by Part Name and City')
plt.xlabel('City')
plt.ylabel('Claim Count')
plt.xticks(rotation=45)
plt.legend(title='Part Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-93-a8fbdc6928ca>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=grouped_df, x='City', y='Claim_Count', hue='Part_Name', ci=None)

# %% [markdown]
# #cehcking pie chart through which city more claimed on parts

# %%
# Group by City and Part_Name to calculate the claim count
claim_counts_by_city = merged_df.groupby(['City', 'Part_Name']).size().reset_index(name='Claim_Count')

# %%
cities = claim_counts_by_city['City'].unique()
cities
# Out:
# array(['ahemadabad', 'banglore', 'cuttack', 'mumbai', 'noida', 'panaji'],
#       dtype=object)

# %%
num_cols = len(cities)
fig, axes = plt.subplots(1, num_cols, figsize=(4 * num_cols, 4))
for i, city in enumerate(cities):
    city_data = claim_counts_by_city[claim_counts_by_city['City'] == city]
    ax = axes[i]
    ax.pie(city_data['Claim_Count'], labels=city_data['Part_Name'], autopct='%1.1f%%', startangle=140)
    ax.set_title(f'Claim Distribution for {city}')
    ax.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# #most claim by city

# %%
claim_counts_by_city = merged_df.groupby('City').size().reset_index(name='Total_Claim_Count')
claim_counts_by_city
# Out:
#          City  Total_Claim_Count
# 0  ahemadabad               1365
# 1    banglore               3819
# 2     cuttack               4613
# 3      mumbai               2120
# 4       noida               4163
# 5      panaji               4015

# %%
plt.pie(claim_counts_by_city['Total_Claim_Count'], labels=claim_counts_by_city['City'], autopct='%1.1f%%', startangle=140)
plt.title('Total Number of Claims by City')
plt.axis('equal')
plt.show()

# %% [markdown]
# #UseCases

# %% [markdown]
# #Monthly report of top ten Dealers and parts that has been failed:

# %%
dealer_claim_counts = df_claims['Dealer_ID'].value_counts().reset_index()
dealer_claim_counts.columns = ['Dealer_ID', 'Claim_Count']

# %%
part_failure_counts = df_claims['Part_ID'].value_counts().reset_index()
part_failure_counts.columns = ['Part_ID', 'Failure_Count']

# %%
# Merge with dealer and part information
dealer_claim_counts = pd.merge(dealer_claim_counts, df_dealers, on='Dealer_ID', how='left')
part_failure_counts = pd.merge(part_failure_counts, df_parts, on='Part_ID', how='left')

# %%
top_ten_dealers = dealer_claim_counts.nlargest(10, 'Claim_Count')
top_ten_parts = part_failure_counts.nlargest(10, 'Failure_Count')

# %%
top_ten_dealers
# Out:
#    Dealer_ID  Claim_Count      Dealer_Name Dealer_Country        State  \
# 0          5          971       Lynn Knapp          india       Orrisa
# 1          3          922  Donald Repinski          india    Karnataka
# 2          2          922  Owen Mclaughlin          india        Delhi
# 3          1          922  Kenneth Schmitt          india          Goa
# 4          6          394     Harold Hamff          india  Maharashtra
# 5          4          218    Rachel Oszust          india       Gujrat
# 6       1248          176     Billy Orozco          india    Karnataka
# 7       1256          176    Bennie Creech          india       Orrisa
# 8       1255          176     Robert Finch          india       Gujrat
# 9       1254          176     Barbara Gray          india    Karnataka
#
#         City  ZIpCode
# 0    Cuttack   400005
# 1  Bangalore   400003
# 2     Naoida   400002
# 3      Panji   400001
# 4     Mumbai   400006
# 5  Ahemdabad   400004
# 6  Bangalore   400003
# ...

# %%
top_ten_parts
# Out:
#    Part_ID  Failure_Count        Part_Name  Manufacturer_ID  Manf_Date
# 0      906           4019         radiator              506 1997-03-24
# 1      901           3349        brake pad              501 1996-08-12
# 2      905           3349  rear suspension              505 1996-08-19
# 3      907           3348      clutch kits              503 1997-05-12
# 4      902           2010            axle               502 1997-03-03
# 5      903           2010          tie rod              503 1997-06-13
# 6      904           2010     differential              504 1997-01-14

# %%
#top ten dealers ploting
plt.bar(top_ten_dealers['Dealer_Name'], top_ten_dealers['Claim_Count'], color='skyblue')
plt.title('Top Ten Dealers by Claim Count')
plt.xlabel('Dealer Name')
plt.ylabel('Claim Count')
plt.xticks(rotation=45)
plt.show()

# %%
#top ten parts
plt.bar(top_ten_parts['Part_Name'], top_ten_parts['Failure_Count'], color='lightcoral')
plt.title('Top Ten Failed Parts by Failure Count')
plt.xlabel('Part Name')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Monthly report of top ten failed parts helps the company to understand following:
# * a) Quality of the parts
# * b) Pattern of failure
# * c) Mostly reported failed part in the quarter/year
#
# * For this above conditions :
#
# * 1 Calculate the number of failures for each part on a monthly basis.
# * 2 Visualize the failure trends over time to identify patterns.
# * 3 Identify the top ten most frequently failed parts on a quarterly and yearly basis.

# %%
#Now i am merging the df claim and part frame for getting different data from them
merged_df = pd.merge(df_claims, df_parts, on='Part_ID', how='left')

# %%
# Convert claim_date to datetime format and extract month and year
merged_df['claim_date'] = pd.to_datetime(merged_df['claim_date'])
merged_df['claim_month'] = merged_df['claim_date'].dt.to_period('M')
merged_df['claim_year'] = merged_df['claim_date'].dt.year
merged_df['claim_quarter'] = merged_df['claim_date'].dt.to_period('Q')

# %%
# Calculating the number of failures for each part per month
monthly_part_failures = merged_df.groupby(['claim_month', 'Part_Name']).size().reset_index(name='Failure_Count')

# %%
#top ten failed parts for each month
top_ten_failed_parts = monthly_part_failures.groupby('claim_month').apply(lambda x: x.nlargest(10, 'Failure_Count')).reset_index(drop=True)

# %%
top_ten_failed_parts
# Out:
#    claim_month        Part_Name  Failure_Count
# 0      2020-04         radiator            268
# 1      2020-04        brake pad            224
# 2      2020-04  rear suspension            223
# 3      2020-04      clutch kits            222
# 4      2020-04          tie rod            135
# ..         ...              ...            ...
# 65     2021-01      clutch kits           3085
# 66     2021-01  rear suspension           3085
# 67     2021-01            axle            1851
# 68     2021-01     differential           1851
# 69     2021-01          tie rod           1851
#
# [70 rows x 3 columns]

# %%
#now i show visulize view for top 10 failed parts
sns.barplot(data=top_ten_failed_parts, x='claim_month', y='Failure_Count', hue='Part_Name')
plt.title('Top Ten Failed Parts by Month')
plt.xlabel('Month')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.legend(title='Part Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
#the number of failures for each part per quarter
quarterly_part_failures = merged_df.groupby(['claim_quarter', 'Part_Name']).size().reset_index(name='Failure_Count')

# %%
quarterly_part_failures
# Out:
#    claim_quarter        Part_Name  Failure_Count
# 0         2020Q2            axle             140
# 1         2020Q2        brake pad            234
# 2         2020Q2      clutch kits            232
# 3         2020Q2     differential            140
# 4         2020Q2         radiator            281
# 5         2020Q2  rear suspension            233
# 6         2020Q2          tie rod            141
# 7         2020Q3            axle               9
# 8         2020Q3        brake pad             15
# 9         2020Q3      clutch kits             16
# 10        2020Q3     differential              9
# 11        2020Q3         radiator             18
# 12        2020Q3  rear suspension             16
# 13        2020Q3          tie rod              9
# 14        2020Q4            axle              10
# 15        2020Q4        brake pad             15
# 16        2020Q4      clutch kits             15
# 17        2020Q4     differential             10
# ...

# %%
#top ten failed parts for each quarter
top_ten_failed_parts_quarter = quarterly_part_failures.groupby('claim_quarter').apply(lambda x: x.nlargest(10, 'Failure_Count')).reset_index(drop=True)

# %%
top_ten_failed_parts_quarter
# Out:
#    claim_quarter        Part_Name  Failure_Count
# 0         2020Q2         radiator            281
# 1         2020Q2        brake pad            234
# 2         2020Q2  rear suspension            233
# 3         2020Q2      clutch kits            232
# 4         2020Q2          tie rod            141
# 5         2020Q2            axle             140
# 6         2020Q2     differential            140
# 7         2020Q3         radiator             18
# 8         2020Q3      clutch kits             16
# 9         2020Q3  rear suspension             16
# 10        2020Q3        brake pad             15
# 11        2020Q3            axle               9
# 12        2020Q3     differential              9
# 13        2020Q3          tie rod              9
# 14        2020Q4         radiator             18
# 15        2020Q4        brake pad             15
# 16        2020Q4      clutch kits             15
# 17        2020Q4  rear suspension             15
# ...

# %%
#top ten failed parts for each quarter
plt.figure(figsize=(8, 6))
sns.barplot(data=top_ten_failed_parts_quarter, x='claim_quarter', y='Failure_Count', hue='Part_Name')
plt.title('Top Ten Failed Parts by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.legend(title='Part Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Overall yearly report for the most reported failed parts
yearly_part_failures = merged_df.groupby(['claim_year', 'Part_Name']).size().reset_index(name='Failure_Count')

# %%
yearly_part_failures
# Out:
#     claim_year        Part_Name  Failure_Count
# 0         2020            axle             159
# 1         2020        brake pad            264
# 2         2020      clutch kits            263
# 3         2020     differential            159
# 4         2020         radiator            317
# 5         2020  rear suspension            264
# 6         2020          tie rod            159
# 7         2021            axle            1851
# 8         2021        brake pad           3085
# 9         2021      clutch kits           3085
# 10        2021     differential           1851
# 11        2021         radiator           3702
# 12        2021  rear suspension           3085
# 13        2021          tie rod           1851

# %%
#top ten failed parts for each year
top_ten_failed_parts_year = yearly_part_failures.groupby('claim_year').apply(lambda x: x.nlargest(10, 'Failure_Count')).reset_index(drop=True)

# %%
top_ten_failed_parts_year
# Out:
#     claim_year        Part_Name  Failure_Count
# 0         2020         radiator            317
# 1         2020        brake pad            264
# 2         2020  rear suspension            264
# 3         2020      clutch kits            263
# 4         2020            axle             159
# 5         2020     differential            159
# 6         2020          tie rod            159
# 7         2021         radiator           3702
# 8         2021        brake pad           3085
# 9         2021      clutch kits           3085
# 10        2021  rear suspension           3085
# 11        2021            axle            1851
# 12        2021     differential           1851
# 13        2021          tie rod           1851

# %%
#top ten failed parts for each year
plt.figure(figsize=(8, 8))
sns.barplot(data=top_ten_failed_parts_year, x='claim_year', y='Failure_Count', hue='Part_Name')
plt.title('Top Ten Failed Parts by Year')
plt.xlabel('Year')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.legend(title='Part Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **here we see the top 10 failed part in each year**

# %% [markdown]
# #Predict the parts that may fail according to the location, mileage and age:
# * - In this case, by analyzing the historical data, we need to predict the parts that can be expected to fail according to the age, km driven and location of the vehicle.
# * - This data helps the company to understand the manufacturing requirements of the part i.e. which part is to be manufactured in what quantity so as to avoid unavailability of the parts when claim is raised for that part.

# %%
#Now I merging the data frame for getting the final result
merged_ct = pd.merge(df_claims, df_transactions, on='claim_id', how='inner')
merged_ctp = pd.merge(merged_ct, df_parts, on='Part_ID', how='inner')
merged_ctpc = pd.merge(merged_ctp, df_customers, on='Cust_ID', how='inner')
# merged_data = pd.merge(merged_ctpc, df_dealers, on='Dealer_ID', how='inner') #here i show me error first thats reason i renaming the columns first

# %%
df_dealers.head()
# Out:
#    Dealer_ID      Dealer_Name Dealer_Country      State       City  ZIpCode
# 0          1  Kenneth Schmitt          india        Goa      Panji   400001
# 1          2  Owen Mclaughlin          india      Delhi     Naoida   400002
# 2          3  Donald Repinski          india  Karnataka  Bangalore   400003
# 3          4    Rachel Oszust          india     Gujrat  Ahemdabad   400004
# 4          5       Lynn Knapp          india     Orrisa    Cuttack   400005

# %%
merged_ctpc.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID_x  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000            5      104      901
# 1        31 2020-04-01         36000           15      104      901
# 2       187 2020-04-02         53000         1232      104      901
# 3       217 2020-04-03         53000         1262      104      901
# 4      4171 2021-01-24         36000         1225      104      901
#
#   Repair_or_Replace month_year  vehicle_age claim_month  ...  \
# 0               rpr    2020-04            4     2020-04  ...
# 1               rpr    2020-04            4     2020-04  ...
# 2              rplc    2020-04            4     2020-04  ...
# 3              rplc    2020-04            4     2020-04  ...
# 4               rpr    2021-01            3     2021-01  ...
#
#    transaction_amount  Part_Name  Manufacturer_ID  Manf_Date  Cust_Name  \
# 0               36000  brake pad              501 1996-08-12    reyansh
# ...

# %%
merged_ctpc.rename(columns={'Dealer_ID_x': 'Dealer_ID'}, inplace=True)

# %%
merged_ctpc.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000          5      104      901
# 1        31 2020-04-01         36000         15      104      901
# 2       187 2020-04-02         53000       1232      104      901
# 3       217 2020-04-03         53000       1262      104      901
# 4      4171 2021-01-24         36000       1225      104      901
#
#   Repair_or_Replace month_year  vehicle_age claim_month  ...  \
# 0               rpr    2020-04            4     2020-04  ...
# 1               rpr    2020-04            4     2020-04  ...
# 2              rplc    2020-04            4     2020-04  ...
# 3              rplc    2020-04            4     2020-04  ...
# 4               rpr    2021-01            3     2021-01  ...
#
#    transaction_amount  Part_Name  Manufacturer_ID  Manf_Date  Cust_Name  \
# 0               36000  brake pad              501 1996-08-12    reyansh
# ...

# %%
#Now the final merged columns here
merged_data = pd.merge(merged_ctpc, df_dealers, on='Dealer_ID', how='inner')

# %%
merged_data.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000          5      104      901
# 1      5387 2021-01-24         61000          5      104      901
# 2      4015 2021-01-24         33000          5      104      902
# 3     18872 2021-01-24         42000          5      104      902
# 4      2643 2021-01-24         45000          5      104      903
#
#   Repair_or_Replace month_year  vehicle_age claim_month  ...  Dealer_ID_y  \
# 0               rpr    2020-04            4     2020-04  ...            5
# 1              rplc    2021-01            3     2021-01  ...            5
# 2               rpr    2021-01            3     2021-01  ...            5
# 3              rplc    2021-01            3     2021-01  ...            5
# 4               rpr    2021-01            3     2021-01  ...            5
#
#   Country  State_x   City_x  ZipCode Dealer_Name Dealer_Country  State_y  \
# ...

# %%
merged_data.columns
# Out:
# Index(['claim_id', 'claim_date', 'claim_amount', 'Dealer_ID', 'Cust_ID',
#        'Part_ID', 'Repair_or_Replace', 'month_year', 'vehicle_age',
#        'claim_month', 'transaction_id', 'transaction_date',
#        'transaction_amount', 'Part_Name', 'Manufacturer_ID', 'Manf_Date',
#        'Cust_Name', 'Dealer_ID_y', 'Country', 'State_x', 'City_x', 'ZipCode',
#        'Dealer_Name', 'Dealer_Country', 'State_y', 'City_y', 'ZIpCode'],
#       dtype='object')

# %%
# Rename columns
merged_data = merged_data.rename(columns={'Country_x': 'Country', 'Country_y': 'Dealer_Country','State_x':'State','City_x':'City'})

# %%
merged_data.head()
# Out:
#    claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0         1 2020-04-01         36000          5      104      901
# 1      5387 2021-01-24         61000          5      104      901
# 2      4015 2021-01-24         33000          5      104      902
# 3     18872 2021-01-24         42000          5      104      902
# 4      2643 2021-01-24         45000          5      104      903
#
#   Repair_or_Replace month_year  vehicle_age claim_month  ...  Dealer_ID_y  \
# 0               rpr    2020-04            4     2020-04  ...            5
# 1              rplc    2021-01            3     2021-01  ...            5
# 2               rpr    2021-01            3     2021-01  ...            5
# 3              rplc    2021-01            3     2021-01  ...            5
# 4               rpr    2021-01            3     2021-01  ...            5
#
#   Country   State     City  ZipCode Dealer_Name Dealer_Country  State_y  \
# ...

# %% [markdown]
# #now we making somefeature engineering in the data for getting some columns

# %%
#creating the part age from the manufcturing date
merged_data['claim_date'] = pd.to_datetime(merged_data['claim_date'])
merged_data['Manf_Date'] = pd.to_datetime(merged_data['Manf_Date'])
merged_data['Part_Age'] = merged_data['claim_date'].dt.year - merged_data['Manf_Date'].dt.year

# %%
import numpy as np

# %%
#creating the milage column based on determined in brd.
merged_data['Mileage'] = np.random.randint(5000, 200000, merged_data.shape[0])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
merged_data['Location'] = label_encoder.fit_transform(merged_data['City'])

# %%
#now i making part failure col..
merged_data['Part_Failure'] = merged_data['Repair_or_Replace'].apply(lambda x: 1 if x == 'rplc' else 0)

# %% [markdown]
# #train the model

# %%
from sklearn.model_selection import train_test_split

# %%
features = ['Part_Age', 'Mileage', 'Location']
X = merged_data[features]
y = merged_data['Part_Failure']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#train model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[ 568 1011]
#  [ 966 3484]]

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.37      0.36      0.36      1579
#            1       0.78      0.78      0.78      4450
#
#     accuracy                           0.67      6029
#    macro avg       0.57      0.57      0.57      6029
# weighted avg       0.67      0.67      0.67      6029

# %%
print("Accuracy Score:\n", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score:
#  0.6720849228727815

# %% [markdown]
# * GradientBoosting Classifier

# %%
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_gb))
print("Classification Report:\n", classification_report(y_test, y_pred_gb))
print("Accuracy Score:", accuracy_score(y_test, y_pred_gb))
# Out:
# Confusion Matrix:
#  [[ 509 1070]
#  [ 476 3974]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.32      0.40      1579
#            1       0.79      0.89      0.84      4450
#
#     accuracy                           0.74      6029
#    macro avg       0.65      0.61      0.62      6029
# weighted avg       0.72      0.74      0.72      6029
#
# Accuracy Score: 0.7435727317963178

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_test['Mileage'], y=X_test['Part_Age'], hue=y_pred_gb, palette='viridis')
plt.title('Predicted Part Failures')
plt.xlabel('Mileage')
plt.ylabel('Part Age')
plt.show()

# %% [markdown]
# * 0: The part is not fail.(repair)
# * 1: The part is predicted to fail.(replced)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
#logitic reg model.
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
logistic_pred = logistic_model.predict(X_test)
logistic_accuracy = accuracy_score(y_test, logistic_pred)

# %%
print("Logistic Regression Accuracy:", logistic_accuracy)
# Out:
# Logistic Regression Accuracy: 0.7380991872615691

# %%
#knn model
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_pred = knn_model.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_pred)

# %%
print("K-Nearest Neighbors Accuracy:", knn_accuracy)
# Out:
# K-Nearest Neighbors Accuracy: 0.6802123071819539

# %%
#svm model
svm_model = SVC()
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
svm_pred = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)

# %%
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 0.7380991872615691

# %%
# Neural Network model
nn_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000)
nn_model.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=1000)

# %%
nn_pred = nn_model.predict(X_test)
nn_accuracy = accuracy_score(y_test, nn_pred)

# %%
print("Neural Network Accuracy:", nn_accuracy)
# Out:
# Neural Network Accuracy: 0.7380991872615691

# %% [markdown]
# * here with help of gradientboosting we able get more accuracy of model

# %% [markdown]
# #To determine whether the defective part is to be replaced or repaired:
# - The model was developed to decide whether the failed part has to be repaired or replaced with the new one.
# - For this, we had the last claimed data of the company.
# - As this is the binary classification problem, Decision tree and Random Forest algorithms are used to build the model.
#
# - To determine whether a defective part should be replaced or repaired, we can develop a binary classification model using the historical claims data. We will use a Decision Tree or Random Forest classifier for this purpose.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
merged_data['Repair_or_Replace'] = label_encoder.fit_transform(merged_data['Repair_or_Replace'])

# %%
features = ['Part_Age', 'Mileage', 'Location']
X = merged_data[features]
y = merged_data['Repair_or_Replace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = dt_model.predict(X_test)

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
# Out:
# Confusion Matrix:
#  [[3434 1016]
#  [1003  576]]

# %%
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      4450
#            1       0.36      0.36      0.36      1579
#
#     accuracy                           0.67      6029
#    macro avg       0.57      0.57      0.57      6029
# weighted avg       0.67      0.67      0.67      6029

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred_dt))
# Out:
# Accuracy Score: 0.6651185934649195

# %%
# Train the Random Forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# Confusion Matrix:
#  [[3484  966]
#  [1012  567]]

# %%
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      4450
#            1       0.37      0.36      0.36      1579
#
#     accuracy                           0.67      6029
#    macro avg       0.57      0.57      0.57      6029
# weighted avg       0.67      0.67      0.67      6029

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy Score: 0.6719190578868801

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_test['Mileage'], y=X_test['Part_Age'], hue=y_pred_rf, palette='viridis')
plt.title('Predicted Repair or Replace')
plt.xlabel('Mileage')
plt.ylabel('Part Age')
plt.show()

# %% [markdown]
# * 0: The part is not fail.(repair)
# * 1: The part is predicted to fail.(replced)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_test['Mileage'], y=X_test['Part_Age'], hue=X_test['Location'], palette='viridis')
plt.title('Predicted Part Failures by City')
plt.xlabel('Mileage')
plt.ylabel('Part Age')
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# #Customer Retention Model:
# - This model helps the company to understand the service provided by the dealers is satisfactory or not.
# - The model analyses the performance of the dealers by considering the customers feedback, churn rate of that location, preference to the other locations by the customers, change of base location etc.
# - The model helps the company to take some regulatory decisions based the performance of dealer.
# - It also helps the company to decide, whether to introduce new schemes, offers etc. to the affected location or to change the dealer.

# %% [markdown]
# #Processing of variety of data:
# - The data were coming from various locations like US, Canada, China, India in huge amount with varying data-types.
# - It was required to club the data and then process it further for the analyzing.
# - Processing large volume of data also caused memory issues which was then handled by memory management.
